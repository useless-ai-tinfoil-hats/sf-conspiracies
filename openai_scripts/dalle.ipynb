# %%
from dotenv import load_dotenv
from openai import OpenAI
from utils import create_intro_paragraph, generate_image, display_image

load_dotenv()
# Out:
# True

# %%
client = OpenAI()
intro = create_intro_paragraph(client, user_prompt="Write me an introductory paragraph about conspiracies related to the 30 Years War.")
image_url = generate_image(client, intro = intro)
display_image(file_path="images", image_url = image_url, save = True)

# %%
print(intro)
# Out:
# In a time when the 30 Years War ravaged Europe from 1618 to 1648, few realize how this historical conflict may have been shaped by clandestine forces still relevant today. As the smoke of battle cleared over fields across the continent, whispers of hidden agendas and secret societies began to surface—elements strikingly reminiscent of today's conspiratorial narratives. But what if I told you that the tendrils of these early machinations can be traced all the way to the bustling alleys of San Francisco? From curious tech moguls dabbling in historical revisionism to forgotten archives revealing the mysterious linkage of the Pacific Heights elite with European power brokers of the past, the spirit of conspiracy thrives in the Bay Area, offering a striking lens through which to view the echoes of the 30 Years War.

# %%
client = OpenAI()
intro = create_intro_paragraph(client, user_prompt="Write me an introductory paragraph about a onspiracy related to Sasquatch.")
image_url = generate_image(client, intro = intro)
display_image(file_path="images", image_url = image_url, save = True)

# %%
print(intro)
# Out:
# In the shadowy corners of the San Francisco Bay Area, a new conspiracy theory is taking root, suggesting that the legendary Sasquatch is not merely a creature of folklore but rather a sophisticated product of tech-driven genetic experimentation. As stories of encounters with this elusive being surface from the dense woods of the Marin Headlands, whispers abound of clandestine biotech firms operating out of Silicon Valley, where scientists might be pushing the boundaries of species manipulation under the guise of conservation efforts. Recent sightings, paired with reports of unusual high-tech equipment left behind in the areas of these sightings, have sparked debate among local enthusiasts, leading to speculations that Sasquatch could very well be a hybrid creation, orchestrated as the ultimate test case for human ingenuity – and perhaps a bigger secret tied to the ever-expanding influence of AI and genetic engineering.
